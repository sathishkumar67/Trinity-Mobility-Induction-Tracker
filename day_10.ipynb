# %%
# !pip install parler_tts
# Out:
# Collecting parler_tts
#   Downloading parler_tts-0.2.3.tar.gz (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting transformers<=4.46.1,>=4.46.1 (from parler_tts)
#   Downloading transformers-4.46.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from parler_tts) (2.8.0+cu126)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from parler_tts) (0.2.1)
# Collecting descript-audio-codec-unofficial (from parler_tts)
#   Downloading descript_audio_codec_unofficial-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting descript-audiotools-unofficial (from parler_tts)
#   Downloading descript_audiotools_unofficial-0.7.4.tar.gz (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.7/100.7 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from parler_tts) (5.29.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (3.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (26.0rc2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (2.32.5)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (0.6.2)
# Collecting tokenizers<0.21,>=0.20 (from transformers<=4.46.1,>=4.46.1->parler_tts)
#   Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts) (4.67.1)
# Collecting argbind>=0.3.7 (from descript-audio-codec-unofficial->parler_tts)
#   Downloading argbind-0.3.9.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from descript-audio-codec-unofficial->parler_tts) (0.8.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from descript-audio-codec-unofficial->parler_tts) (2.8.0+cu126)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (0.13.1)
# Collecting pyloudnorm (from descript-audiotools-unofficial->parler_tts)
#   Downloading pyloudnorm-0.2.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (6.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (1.15.3)
# Collecting julius (from descript-audiotools-unofficial->parler_tts)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (0.6.3)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (7.34.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (14.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (3.10.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (0.11.0)
# Collecting pystoi (from descript-audiotools-unofficial->parler_tts)
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting torch_stoi (from descript-audiotools-unofficial->parler_tts)
#   Downloading torch_stoi-0.2.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting flatten-dict (from descript-audiotools-unofficial->parler_tts)
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting markdown2 (from descript-audiotools-unofficial->parler_tts)
#   Downloading markdown2-2.5.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting randomname (from descript-audiotools-unofficial->parler_tts)
#   Downloading randomname-0.2.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting protobuf>=4.0.0 (from parler_tts)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from descript-audiotools-unofficial->parler_tts) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->parler_tts) (3.4.0)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.12/dist-packages (from argbind>=0.3.7->descript-audio-codec-unofficial->parler_tts) (0.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers<=4.46.1,>=4.46.1->parler_tts) (1.2.1rc0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->parler_tts) (1.3.0)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.12/dist-packages (from flatten-dict->descript-audiotools-unofficial->parler_tts) (1.17.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->descript-audiotools-unofficial->parler_tts) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->parler_tts) (3.0.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (1.5.3)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->descript-audiotools-unofficial->parler_tts) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->descript-audiotools-unofficial->parler_tts) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->descript-audiotools-unofficial->parler_tts) (2.9.0.post0)
# Collecting fire (from randomname->descript-audiotools-unofficial->parler_tts)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->descript-audiotools-unofficial->parler_tts) (4.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->descript-audiotools-unofficial->parler_tts) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->descript-audiotools-unofficial->parler_tts) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->descript-audiotools-unofficial->parler_tts) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->descript-audiotools-unofficial->parler_tts) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->descript-audiotools-unofficial->parler_tts) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->descript-audiotools-unofficial->parler_tts) (2.23)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->descript-audiotools-unofficial->parler_tts) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools-unofficial->parler_tts) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->descript-audiotools-unofficial->parler_tts) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->descript-audiotools-unofficial->parler_tts) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->descript-audiotools-unofficial->parler_tts) (4.5.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->descript-audiotools-unofficial->parler_tts) (0.2.14)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->descript-audiotools-unofficial->parler_tts) (3.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->randomname->descript-audiotools-unofficial->parler_tts) (3.1.0)
# Downloading transformers-4.46.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 84.0 MB/s eta 0:00:00:00:01:01
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 19.3 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 95.8 MB/s eta 0:00:00
# Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Downloading markdown2-2.5.4-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 2.2 MB/s eta 0:00:00
# Downloading pyloudnorm-0.2.0-py3-none-any.whl (10 kB)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Downloading torch_stoi-0.2.3-py3-none-any.whl (8.1 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 9.0 MB/s eta 0:00:00
# Building wheels for collected packages: parler_tts, descript-audio-codec-unofficial, descript-audiotools-unofficial, argbind, julius, randomname
#   Building wheel for parler_tts (pyproject.toml) ... done
#   Created wheel for parler_tts: filename=parler_tts-0.2.3-py3-none-any.whl size=81609 sha256=155776c513a4e1ca87fb8b6b094e9c55ad6131d9ecdf07f8bba19162f56c2455
#   Stored in directory: /root/.cache/pip/wheels/73/42/0f/e10a7a5392518023cab47114d0b3fbf64752cbb9fd75deaf4d
#   Building wheel for descript-audio-codec-unofficial (setup.py) ... done
#   Created wheel for descript-audio-codec-unofficial: filename=descript_audio_codec_unofficial-1.0.0-py3-none-any.whl size=27053 sha256=5e78e66509b1291e445fe2e0843e8992f3dd50c70b747f98fdbd697480b3bcb7
#   Stored in directory: /root/.cache/pip/wheels/8a/5c/af/8d99ad90c9054a420a64aac0f8ff5ee3f5f77ea2b336c45c21
#   Building wheel for descript-audiotools-unofficial (setup.py) ... done
#   Created wheel for descript-audiotools-unofficial: filename=descript_audiotools_unofficial-0.7.4-py2.py3-none-any.whl size=108048 sha256=de4a5654c48d083430a55b78adee622a33eb3b9563d1994c97d6444f5fa3db72
#   Stored in directory: /root/.cache/pip/wheels/29/3d/40/6a9f86f8ab0cb6668416436b78a20afdb6d2f12b412b65fc0a
#   Building wheel for argbind (setup.py) ... done
#   Created wheel for argbind: filename=argbind-0.3.9-py2.py3-none-any.whl size=11730 sha256=9736cb54f5c6161b49cc79f271c0d64831f7f353a08b65f0e977ee638ece43c7
#   Stored in directory: /root/.cache/pip/wheels/eb/33/cb/c5e898b01c657604d61ef1462002dee37ed67b4b05b871dc45
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21870 sha256=dea6cf2d14aa2d61ee44ef2405527a561296c87f63cf7444ef12bd516fefaeca
#   Stored in directory: /root/.cache/pip/wheels/de/c1/ca/544dafe48401e8e2e17064dfe465a390fca9e8720ffa12e744
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.2.1-py3-none-any.whl size=89194 sha256=6f12a7b343f1282105a66b66f5d207dca8d8019f74fe5e65b46d0507e35cea26
#   Stored in directory: /root/.cache/pip/wheels/05/6e/37/1db72aaa77a57f2dcbc97fd96a47f14091130a1dde562124c0
# Successfully built parler_tts descript-audio-codec-unofficial descript-audiotools-unofficial argbind julius randomname
# Installing collected packages: protobuf, markdown2, flatten-dict, fire, argbind, randomname, pystoi, pyloudnorm, tokenizers, transformers, julius, torch_stoi, descript-audiotools-unofficial, descript-audio-codec-unofficial, parler_tts
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.22.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# a2a-sdk 0.3.22 requires protobuf>=5.29.5, but you have protobuf 4.25.8 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed argbind-0.3.9 descript-audio-codec-unofficial-1.0.0 descript-audiotools-unofficial-0.7.4 fire-0.7.1 flatten-dict-0.4.2 julius-0.2.7 markdown2-2.5.4 parler_tts-0.2.3 protobuf-4.25.8 pyloudnorm-0.2.0 pystoi-0.4.1 randomname-0.2.1 tokenizers-0.20.3 torch_stoi-0.2.3 transformers-4.46.1

# %%
import torch
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer
import soundfile as sf

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = ParlerTTSForConditionalGeneration.from_pretrained("parler-tts/parler-tts-mini-v1").to(device)
tokenizer = AutoTokenizer.from_pretrained("parler-tts/parler-tts-mini-v1")

prompt = "Hey, how are you doing today?"
description = "A female speaker delivers a slightly expressive and animated speech with a moderate speed and pitch. The recording is of very high quality, with the speaker's voice sounding clear and very close up."

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()
sf.write("parler_tts_out.wav", audio_arr, model.config.sampling_rate)

# %%
from transformers import AutoModel
import torch, torchaudio

model = AutoModel.from_pretrained("ai4bharat/indic-conformer-600m-multilingual", trust_remote_code=True)

# Load an audio file
wav, sr = torchaudio.load("tamil.mp3")
wav = torch.mean(wav, dim=0, keepdim=True)

target_sample_rate = 16000  # Expected sample rate
if sr != target_sample_rate:
    resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=target_sample_rate)
    wav = resampler(wav)

# Perform ASR with CTC decoding
transcription_ctc = model(wav, "ta", "ctc")
print("CTC Transcription:", transcription_ctc)
