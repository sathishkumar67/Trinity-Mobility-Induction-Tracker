# %%
import numpy as np

def cosine_similarity(a, b):
    a = np.array(a)
    b = np.array(b)
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

v1 = [0.2, 0.4, 0.6]
v2 = [0.1, 0.3, 0.5]

print(cosine_similarity(v1, v2))
# Out:
# 0.9938586931957764

# %%
def normalize(v):
    v = np.array(v)
    return v / np.linalg.norm(v)

v1_n = normalize(v1)
v2_n = normalize(v2)

print(np.dot(v1_n, v2_n))
# Out:
# 0.9938586931957764

# %%
# !pip install chromadb

# %%
import chromadb
from chromadb.config import Settings

client = chromadb.Client(
    Settings(
        persist_directory="./chroma_db",
        anonymized_telemetry=False
    )
)

# %%
collection = client.get_or_create_collection(
    name="docs",
    metadata={"hnsw:space": "cosine"}
)

# %%
collection.add(
    ids=["doc1", "doc2", "doc3"],
    documents=[
        "Deep learning is powerful",
        "Transformers are amazing",
        "Cats are cute animals"
    ],
    embeddings=[
        [0.1, 0.2, 0.3],
        [0.2, 0.1, 0.4],
        [0.9, 0.8, 0.7]
    ],
    metadatas=[
        {"topic": "ai", "year": 2024},
        {"topic": "ai", "year": 2023},
        {"topic": "animals", "year": 2022}
    ]
)

# %%
results = collection.query(
    query_embeddings=[[0.15, 0.15, 0.35]],
    n_results=2
)

print(results)
# Out:
# {'ids': [['doc2', 'doc1']], 'embeddings': None, 'documents': [['Transformers are amazing', 'Deep learning is powerful']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'year': 2023, 'topic': 'ai'}, {'year': 2024, 'topic': 'ai'}]], 'distances': [[0.013596415519714355, 0.020465314388275146]]}

# %%
results = collection.query(
    query_embeddings=[[0.15, 0.15, 0.35]],
    where={"topic": "ai"},
    n_results=2
)

print(results)
# Out:
# {'ids': [['doc2', 'doc1']], 'embeddings': None, 'documents': [['Transformers are amazing', 'Deep learning is powerful']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'topic': 'ai', 'year': 2023}, {'year': 2024, 'topic': 'ai'}]], 'distances': [[0.013596415519714355, 0.020465314388275146]]}

# %%
collection.update(
    ids=["doc3"],
    metadatas=[{"topic": "pets", "year": 2024}]
)

# %%
collection.delete(ids=["doc1"])

# %%
# !pip install pymilvus milvus-lite
# Out:
# Requirement already satisfied: pymilvus in /usr/local/lib/python3.12/dist-packages (2.6.8)
# Collecting milvus-lite
#   Downloading milvus_lite-2.5.1-py3-none-manylinux2014_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (75.2.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (1.75.1)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (3.11.3)
# Requirement already satisfied: protobuf>=5.27.2 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (5.29.5)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (1.1.1)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: cachetools>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pymilvus) (5.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from milvus-lite) (4.67.1)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2->pymilvus) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.4->pymilvus) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.4->pymilvus) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.4->pymilvus) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)
# Downloading milvus_lite-2.5.1-py3-none-manylinux2014_x86_64.whl (55.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 MB 37.9 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: milvus-lite
# Successfully installed milvus-lite-2.5.1

# %%
from pymilvus import MilvusClient

client = MilvusClient("milvus.db")

client.create_collection(
    collection_name="docs",
    dimension=3
)

client.insert(
    collection_name="docs",
    data=[
        {"id": 1, "vector": [0.1, 0.2, 0.3]},
        {"id": 2, "vector": [0.2, 0.1, 0.4]}
    ]
)

results = client.search(
    collection_name="docs",
    data=[[0.15, 0.15, 0.35]],
    limit=2
)

print(results)
# Out:
# data: [[{'id': 2, 'distance': 0.9864036440849304, 'entity': {}}, {'id': 1, 'distance': 0.9795348048210144, 'entity': {}}]]
